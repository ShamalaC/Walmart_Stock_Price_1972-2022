# %%
class TwoPowerXHeap:
    def __init__(self, x):
        self.x = x
        self.heap = []

    def parent(self, i):
        return (i - 1) // (2 ** self.x)

    def first_child(self, i):
        return (2 ** self.x) * i + 1

    def insert(self, value):
        # Append the new value at the end of the heap
        self.heap.append(value)
        # Bubble up to maintain heap property
        self._bubble_up(len(self.heap) - 1)

    def pop_max(self):
        if len(self.heap) == 0:
            return None
        if len(self.heap) == 1:
            return self.heap.pop()

        # The root is the max element
        max_value = self.heap[0]
        # Move the last element to the root and remove the last element
        self.heap[0] = self.heap.pop()
        # Bubble down to maintain heap property
        self._bubble_down(0)
        
        return max_value

    def _bubble_up(self, index):
        while index > 0:
            parent_index = self.parent(index)
            if self.heap[index] > self.heap[parent_index]:
                # Swap the current element with its parent
                self.heap[index], self.heap[parent_index] = self.heap[parent_index], self.heap[index]
                index = parent_index
            else:
                break

    def _bubble_down(self, index):
        while True:
            first_child_index = self.first_child(index)
            max_index = index

            for i in range(2 ** self.x):
                child_index = first_child_index + i
                if child_index < len(self.heap) and self.heap[child_index] > self.heap[max_index]:
                    max_index = child_index

            if max_index == index:
                break

            # Swap the current element with the largest child
            self.heap[index], self.heap[max_index] = self.heap[max_index], self.heap[index]
            index = max_index

# Example Usage
heap = TwoPowerXHeap(x=2)  # This means each node has 2^2 = 4 children
heap.insert(10)
heap.insert(20)
heap.insert(15)
heap.insert(30)

print(heap.pop_max())  
print(heap.pop_max())  
print(heap.pop_max())  
print(heap.pop_max())
# Out:
# 30
# 20
# 15
# 10

# %% [markdown]
# # Step 1:
# ## The Problem
# The task is to implement a modified heap where each node can have 2^x children instead of the usual 2 children in a binary heap. To implement two operations:
#
# 1. Insert: Add a new element to the heap while maintaining the heap property.
# 2. Pop Max: Remove and return the maximum element from the heap while maintaining the heap property.
#
# # Step 2:
# ## Defining the Heap Structure
# A heap is usually implemented as an array (or list in Python). The key property of a heap is that each parent node is greater than or equal to its children (in a max-heap).
#
# In a 2^x-ary heap:
#
# Each node has 2^x children.
# The heap is still a complete tree, meaning all levels are fully filled except possibly the last level, which is filled from left to right.
#
# # Step 3:
# ## Calculate Parent and Child Indices
# To maintain the heap structure, calculate the parent and child indices in the list.
#
# ## Parent Index Calculation:
#
# For a node at index i, its parent is located at:
# ### parent (𝑖) = 𝑖 − 1 / 2^𝑥
# This formula ensures that each parent has 2^x children.
#
# ## Child Indices Calculation:
#
# The children of a node at index i start at:
# ### first_child (𝑖) = 2^𝑥 * i+1
#
# The children of this node are located from first_child(i) to first_child(i) + 2^x - 1.
#
# # Step 4:
# ## Implement the Insert Operation
# The insert operation involves the following steps:
# 1. Append the new element at the end of the heap (i.e., add it to the last position in the list).
# 2. Bubble up the new element to restore the heap property:
# 3. Compare the new element with its parent.
# 4. If the new element is greater than its parent, swap them.
# 5. Continue this process until the element is in the correct position, or it becomes the root (i.e., no more parents to compare).
#
# # Step 5:
# ### Implement the Pop Max Operation
# The pop max operation involves the following steps:
# 1. Remove the root element (which is the maximum element in a max-heap).
# 2. Replace the root with the last element in the heap.
# 3. Bubble down the new root element to restore the heap property:
# 4. Compare the new root with its children.
# 5. Swap the root with the largest child if the child is greater.
# 6. Continue this process until the element is in the correct position, or it has no children that are larger.
#
# # Step 6:
# ### Analyze the Complexity
# # Time Complexity:
# Insert: 𝑂(log𝑛/𝑥)
# Pop Max: 𝑂(log𝑛/𝑥)
#
# The time complexity is minimized by choosing a large x, which reduces the height of the heap.
#
# # Space Complexity:
# 𝑂 (𝑛), where n is the number of elements in the heap. The list used to store the heap elements takes linear space.
